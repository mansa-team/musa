# %%
import os
os.environ["HF_TOKEN"] = "TOKEN"
os.environ["HUGGING_FACE_HUB_TOKEN"] = os.environ["HF_TOKEN"]

# !test -d /content/musa/.git || git clone --filter=blob:none --sparse https://github.com/mansa-team/musa.git /content/musa
# !git -C /content/musa sparse-checkout set logun 2>/dev/null; git -C /content/musa pull --ff-only

# %cd /content/musa

# !test -f logun/dataset/data/output/corpus-250M.jsonl || hf download heitorrosa/logun-base corpus-250M.jsonl --local-dir logun/dataset/data/output

# %pip install torch torchao==0.16.0 peft transformers datasets
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), 314 bytes | 314.00 KiB/s, done.
# Resolving deltas: 100% (2/2), completed with 2 local objects.
# From https://github.com/mansa-team/musa
#    d9a72e7..fca3b3e  main       -> origin/main
# Updating d9a72e7..fca3b3e
# remote: Enumerating objects: 1, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 1 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (1/1), 1.28 KiB | 1.28 MiB/s, done.
# Fast-forward
#  logun/train-dapt.py | 7 ++++---
#  1 file changed, 4 insertions(+), 3 deletions(-)
# /content/musa
# ...

# %%
# !python logun/dapt.py --resume
# Out:
# Skipping import of cpp extensions due to incompatible torch version 2.11.0+cu128 for torchao version 0.16.0             Please see https://github.com/pytorch/ao/issues/2919 for more info
# Loading weights: 100% 137/137 [00:00<00:00, 717.64it/s]
#   0% 0/8637 [00:00<?, ?it/s][transformers] `use_return_dict` is deprecated! Use `return_dict` instead!
# {'loss': '0.7013', 'grad_norm': '0.0855', 'learning_rate': '4.9e-06', 'epoch': '0.008685'}
# {'loss': '0.7034', 'grad_norm': '0.1041', 'learning_rate': '9.9e-06', 'epoch': '0.01737'}
# {'loss': '0.7068', 'grad_norm': '0.1294', 'learning_rate': '1.49e-05', 'epoch': '0.02605'}
# {'loss': '0.6828', 'grad_norm': '0.1333', 'learning_rate': '1.99e-05', 'epoch': '0.03474'}
# {'loss': '0.6825', 'grad_norm': '0.1479', 'learning_rate': '2.49e-05', 'epoch': '0.04342'}
# {'loss': '0.6635', 'grad_norm': '0.07012', 'learning_rate': '2.99e-05', 'epoch': '0.05211'}
# ...
